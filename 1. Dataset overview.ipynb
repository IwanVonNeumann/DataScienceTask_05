# %% [markdown]
# # Dataset overview

# %%
import os
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

from utils import get_target_pivot, merge_rare, enumerate_float
from feature_engineering import generate_event_features

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.float_format', '{:.3f}'.format)

# %% [markdown]
# ## 1. Dataset import

# %%
DATA_DIR = 'data'

# %%
USERS_FILE_NAME = 'user_profile.csv'
EVENTS_FILE_NAME = 'events.csv'

# %%
users_file_path = os.path.join(DATA_DIR, USERS_FILE_NAME)
events_file_path = os.path.join(DATA_DIR, EVENTS_FILE_NAME)

# %%
df = pd.read_csv(users_file_path).set_index('user_id').sort_index()

# %%
events_df = pd.read_csv(events_file_path)

# %%
df['reg_ts'] = pd.to_datetime(df['reg_ts'], unit='s')

# %%
events_df['event_ts'] = pd.to_datetime(events_df['event_ts'], unit='s')

# %%
df.rename(columns={'target': 'ltv_30'}, inplace=True)

# %%
df.shape
# Out:
# (4862, 4)

# %%
events_df.shape
# Out:
# (423862, 4)

# %%
df.head()
# Out:
#                      reg_ts country entry_point   ltv_30
# user_id
# 1       2025-01-01 02:06:17      US     android 1468.187
# 2       2025-01-01 08:06:23      PL     android  619.849
# 3       2025-01-01 13:07:50      US     android   97.804
# 4       2025-01-01 15:21:41      HU     android   71.662
# 5       2025-01-02 07:27:59      PL     android    0.000

# %%
events_df.head()
# Out:
#              event_ts  user_id event_name  event_value
# 0 2025-01-01 04:41:50      843    payment       23.710
# 1 2025-01-01 05:23:58     2605    payment       24.451
# 2 2025-01-01 06:31:28     3715    payment       24.451
# 3 2025-01-01 06:41:23     3715    payment       24.451
# 4 2025-01-01 06:52:47     3715    payment       24.451

# %%
TARGET = 'ltv_30'

# %% [markdown]
# ## 2. Users data overview

# %%
df[TARGET].sum()
# Out:
# np.float64(706138.8474897386)

# %%
df[TARGET].mean()
# Out:
# np.float64(145.2362911332247)

# %%
(df[TARGET] == 0).mean()
# Out:
# np.float64(0.637186343068696)

# %% [markdown]
# ### 2.1. `entry_point`

# %%
get_target_pivot(df, col='entry_point', target_col=TARGET)
# Out:
# <style type="text/css">
# #T_c3c01_row0_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_c3c01_row1_col0 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_c3c01_row2_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c3c01">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3c01_level0_col0" class="col_heading level0 col0" >ltv_30</th>
#       <th id="T_c3c01_level0_col1" class="col_heading level0 col1" >n_users</th>
#       <th id="T_c3c01_level0_col2" class="col_heading level0 col2" >%_users</th>
#       <th id="T_c3c01_level0_col3" class="col_heading level0 col3" >%_rev</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >entry_point</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3c01_level0_row0" class="row_heading level0 row0" >web</th>
#       <td id="T_c3c01_row0_col0" class="data row0 col0" >892.33</td>
#       <td id="T_c3c01_row0_col1" class="data row0 col1" >57</td>
#       <td id="T_c3c01_row0_col2" class="data row0 col2" >1.2%</td>
#       <td id="T_c3c01_row0_col3" class="data row0 col3" >7.2%</td>
#     </tr>
#     <tr>
#       <th id="T_c3c01_level0_row1" class="row_heading level0 row1" >ios</th>
#       <td id="T_c3c01_row1_col0" class="data row1 col0" >225.35</td>
#       <td id="T_c3c01_row1_col1" class="data row1 col1" >778</td>
#       <td id="T_c3c01_row1_col2" class="data row1 col2" >16.0%</td>
#       <td id="T_c3c01_row1_col3" class="data row1 col3" >24.8%</td>
#     </tr>
#     <tr>
#       <th id="T_c3c01_level0_row2" class="row_heading level0 row2" >android</th>
#       <td id="T_c3c01_row2_col0" class="data row2 col0" >119.18</td>
#       <td id="T_c3c01_row2_col1" class="data row2 col1" >4 027</td>
#       <td id="T_c3c01_row2_col2" class="data row2 col2" >82.8%</td>
#       <td id="T_c3c01_row2_col3" class="data row2 col3" >68.0%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df['entry_point=android'] = (df['entry_point'] == 'android').astype(int)

# %%
get_target_pivot(df, col='entry_point=android', target_col=TARGET)
# Out:
# <style type="text/css">
# #T_3f1b8_row0_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_3f1b8_row1_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3f1b8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f1b8_level0_col0" class="col_heading level0 col0" >ltv_30</th>
#       <th id="T_3f1b8_level0_col1" class="col_heading level0 col1" >n_users</th>
#       <th id="T_3f1b8_level0_col2" class="col_heading level0 col2" >%_users</th>
#       <th id="T_3f1b8_level0_col3" class="col_heading level0 col3" >%_rev</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >entry_point=android</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f1b8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3f1b8_row0_col0" class="data row0 col0" >270.88</td>
#       <td id="T_3f1b8_row0_col1" class="data row0 col1" >835</td>
#       <td id="T_3f1b8_row0_col2" class="data row0 col2" >17.2%</td>
#       <td id="T_3f1b8_row0_col3" class="data row0 col3" >32.0%</td>
#     </tr>
#     <tr>
#       <th id="T_3f1b8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3f1b8_row1_col0" class="data row1 col0" >119.18</td>
#       <td id="T_3f1b8_row1_col1" class="data row1 col1" >4 027</td>
#       <td id="T_3f1b8_row1_col2" class="data row1 col2" >82.8%</td>
#       <td id="T_3f1b8_row1_col3" class="data row1 col3" >68.0%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 2.2. `country`

# %%
df['country'].value_counts().head(10)
# Out:
# country
# US    737
# BR    262
# FR    259
# DE    252
# IN    221
# TR    218
# PL    214
# IT    179
# GB    162
# ES    150
# Name: count, dtype: int64

# %%
df['country'] = merge_rare(df['country'])

# %%
get_target_pivot(df, col='country', target_col=TARGET)
# Out:
# <style type="text/css">
# #T_a1b0c_row0_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_a1b0c_row1_col0 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_a1b0c_row2_col0 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_a1b0c_row3_col0 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_a1b0c_row4_col0 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_a1b0c_row5_col0 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_a1b0c_row6_col0 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_a1b0c_row7_col0, #T_a1b0c_row8_col0 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_a1b0c_row9_col0 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_a1b0c_row10_col0 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_a1b0c_row11_col0 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_a1b0c_row12_col0 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_a1b0c_row13_col0 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_a1b0c_row14_col0 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_a1b0c_row15_col0 {
#   background-color: #bd1726;
#   color: #f1f1f1;
# }
# #T_a1b0c_row16_col0 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_a1b0c_row17_col0 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_a1b0c_row18_col0 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_a1b0c_row19_col0 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_a1b0c_row20_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a1b0c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1b0c_level0_col0" class="col_heading level0 col0" >ltv_30</th>
#       <th id="T_a1b0c_level0_col1" class="col_heading level0 col1" >n_users</th>
#       <th id="T_a1b0c_level0_col2" class="col_heading level0 col2" >%_users</th>
#       <th id="T_a1b0c_level0_col3" class="col_heading level0 col3" >%_rev</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1b0c_level0_row0" class="row_heading level0 row0" >CH</th>
#       <td id="T_a1b0c_row0_col0" class="data row0 col0" >456.60</td>
#       <td id="T_a1b0c_row0_col1" class="data row0 col1" >55</td>
#       <td id="T_a1b0c_row0_col2" class="data row0 col2" >1.1%</td>
#       <td id="T_a1b0c_row0_col3" class="data row0 col3" >3.6%</td>
#     </tr>
#     <tr>
#       <th id="T_a1b0c_level0_row1" class="row_heading level0 row1" >GB</th>
#       <td id="T_a1b0c_row1_col0" class="data row1 col0" >340.63</td>
#       <td id="T_a1b0c_row1_col1" class="data row1 col1" >162</td>
#       <td id="T_a1b0c_row1_col2" class="data row1 col2" >3.3%</td>
#       <td id="T_a1b0c_row1_col3" class="data row1 col3" >7.8%</td>
#     </tr>
#     <tr>
#       <th id="T_a1b0c_level0_row2" class="row_heading level0 row2" >US</th>
#       <td id="T_a1b0c_row2_col0" class="data row2 col0" >290.42</td>
#       <td id="T_a1b0c_row2_col1" class="data row2 col1" >737</td>
#       <td id="T_a1b0c_row2_col2" class="data row2 col2" >15.2%</td>
#       <td id="T_a1b0c_row2_col3" class="data row2 col3" >30.3%</td>
#     </tr>
#     <tr>
#       <th id="T_a1b0c_level0_row3" class="row_heading level0 row3" >DE</th>
#       <td id="T_a1b0c_row3_col0" class="data row3 col0" >283.55</td>
#       <td id="T_a1b0c_row3_col1" class="data row3 col1" >252</td>
#       <td id="T_a1b0c_row3_col2" class="data row3 col2" >5.2%</td>
#       <td id="T_a1b0c_row3_col3" class="data row3 col3" >10.1%</td>
#     </tr>
#     <tr>
#       <th id="T_a1b0c_level0_row4" class="row_heading level0 row4" >RO</th>
#       <td id="T_a1b0c_row4_col0" class="data row4 col0" >231.55</td>
#       <td id="T_a1b0c_row4_col1" class="data row4 col1" >63</td>
#       <td id="T_a1b0c_row4_col2" class="data row4 col2" >1.3%</td>
#       <td id="T_a1b0c_row4_col3" class="data row4 col3" >2.1%</td>
#     </tr>
#     <tr>
#       <th id="T_a1b0c_level0_row5" class="row_heading level0 row5" >CA</th>
#       <td id="T_a1b0c_row5_col0" class="data row5 col0" >230.07</td>
#       <td id="T_a1b0c_row5_col1" class="data row5 col1" >70</td>
#       <td id="T_a1b0c_row5_col2" class="data row5 col2" >1.4%</td>
#       <td id="T_a1b0c_row5_col3" class="data row5 col3" >2.3%</td>
#     </tr>
#     <tr>
#       <th id="T_a1b0c_level0_row6" class="row_heading level0 row6" >AU</th>
#       <td id="T_a1b0c_row6_col0" class="data row6 col0" >175.74</td>
#       <td id="T_a1b0c_row6_col1" class="data row6 col1" >73</td>
#       <td id="T_a1b0c_row6_col2" class="data row6 col2" >1.5%</td>
#       <td id="T_a1b0c_row6_col3" class="data row6 col3" >1.8%</td>
#     </tr>
#     <tr>
#       <th id="T_a1b0c_level0_row7" class="row_heading level0 row7" >PL</th>
#       <td id="T_a1b0c_row7_col0" class="data row7 col0" >156.29</td>
#       <td id="T_a1b0c_row7_col1" class="data row7 col1" >214</td>
#       <td id="T_a1b0c_row7_col2" class="data row7 col2" >4.4%</td>
#       <td id="T_a1b0c_row7_col3" class="data row7 col3" >4.7%</td>
#     </tr>
#     <tr>
#       <th id="T_a1b0c_level0_row8" class="row_heading level0 row8" >IT</th>
#       <td id="T_a1b0c_row8_col0" class="data row8 col0" >156.09</td>
#       <td id="T_a1b0c_row8_col1" class="data row8 col1" >179</td>
#       <td id="T_a1b0c_row8_col2" class="data row8 col2" >3.7%</td>
#       <td id="T_a1b0c_row8_col3" class="data row8 col3" >4.0%</td>
#     </tr>
#     <tr>
#       <th id="T_a1b0c_level0_row9" class="row_heading level0 row9" >ES</th>
#       <td id="T_a1b0c_row9_col0" class="data row9 col0" >150.77</td>
#       <td id="T_a1b0c_row9_col1" class="data row9 col1" >150</td>
#       <td id="T_a1b0c_row9_col2" class="data row9 col2" >3.1%</td>
#       <td id="T_a1b0c_row9_col3" class="data row9 col3" >3.2%</td>
#     </tr>
#     <tr>
#       <th id="T_a1b0c_level0_row10" class="row_heading level0 row10" >FR</th>
#       <td id="T_a1b0c_row10_col0" class="data row10 col0" >128.81</td>
#       <td id="T_a1b0c_row10_col1" class="data row10 col1" >259</td>
#       <td id="T_a1b0c_row10_col2" class="data row10 col2" >5.3%</td>
#       <td id="T_a1b0c_row10_col3" class="data row10 col3" >4.7%</td>
#     </tr>
#     <tr>
#       <th id="T_a1b0c_level0_row11" class="row_heading level0 row11" >ZA</th>
#       <td id="T_a1b0c_row11_col0" class="data row11 col0" >105.02</td>
#       <td id="T_a1b0c_row11_col1" class="data row11 col1" >87</td>
#       <td id="T_a1b0c_row11_col2" class="data row11 col2" >1.8%</td>
#       <td id="T_a1b0c_row11_col3" class="data row11 col3" >1.3%</td>
#     </tr>
#     <tr>
#       <th id="T_a1b0c_level0_row12" class="row_heading level0 row12" >OTHER</th>
#       <td id="T_a1b0c_row12_col0" class="data row12 col0" >88.71</td>
#       <td id="T_a1b0c_row12_col1" class="data row12 col1" >1 460</td>
#       <td id="T_a1b0c_row12_col2" class="data row12 col2" >30.0%</td>
#       <td id="T_a1b0c_row12_col3" class="data row12 col3" >18.3%</td>
#     </tr>
#     <tr>
#       <th id="T_a1b0c_level0_row13" class="row_heading level0 row13" >TR</th>
#       <td id="T_a1b0c_row13_col0" class="data row13 col0" >81.80</td>
#       <td id="T_a1b0c_row13_col1" class="data row13 col1" >218</td>
#       <td id="T_a1b0c_row13_col2" class="data row13 col2" >4.5%</td>
#       <td id="T_a1b0c_row13_col3" class="data row13 col3" >2.5%</td>
#     </tr>
#     <tr>
#       <th id="T_a1b0c_level0_row14" class="row_heading level0 row14" >BR</th>
#       <td id="T_a1b0c_row14_col0" class="data row14 col0" >46.15</td>
#       <td id="T_a1b0c_row14_col1" class="data row14 col1" >262</td>
#       <td id="T_a1b0c_row14_col2" class="data row14 col2" >5.4%</td>
#       <td id="T_a1b0c_row14_col3" class="data row14 col3" >1.7%</td>
#     </tr>
#     <tr>
#       <th id="T_a1b0c_level0_row15" class="row_heading level0 row15" >CL</th>
#       <td id="T_a1b0c_row15_col0" class="data row15 col0" >33.09</td>
#       <td id="T_a1b0c_row15_col1" class="data row15 col1" >49</td>
#       <td id="T_a1b0c_row15_col2" class="data row15 col2" >1.0%</td>
#       <td id="T_a1b0c_row15_col3" class="data row15 col3"

# %%
country_rank = df[['country', 'ltv_30']].groupby(by='country').mean()['ltv_30'].sort_values(ascending=False).index.tolist()
# country_rank

# %%
country_ranks_dict = dict(zip(country_rank, range(1, len(country_rank) + 1)))
country_ranks_dict
# Out:
# {'CH': 1,
#  'GB': 2,
#  'US': 3,
#  'DE': 4,
#  'RO': 5,
#  'CA': 6,
#  'AU': 7,
#  'PL': 8,
#  'IT': 9,
#  'ES': 10,
#  'FR': 11,
#  'ZA': 12,
#  'OTHER': 13,
#  'TR': 14,
#  'BR': 15,
#  'CL': 16,
#  'AR': 17,
#  'KZ': 18,
#  'IN': 19,
#  'PK': 20,
#  'MX': 21}

# %%
df['country_e'] = df['country'].map(country_ranks_dict)

# %%
# get_target_pivot(df, col='country_e', target_col=TARGET)

# %% [markdown]
# ## 3. Events data overview

# %%
events_df['event_name'].value_counts()
# Out:
# event_name
# battle             179286
# wealth_on_login     83677
# login               83677
# finish_quest        47922
# level_up            24286
# payment              5014
# Name: count, dtype: int64

# %%
df = df.join(generate_event_features(df, events_df), how='left')

# %% [markdown]
# ### 3.1. `battle`

# %%
df['battles_won_d0_q'] = enumerate_float(df['battles_won_d0'], q=5, process_zeros=True)
df['battles_won_d7_q'] = enumerate_float(df['battles_won_d7'], q=9, process_zeros=True)

# %%
get_target_pivot(df, col='battles_won_d0_q', target_col=TARGET)
# Out:
# <style type="text/css">
# #T_a3163_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_a3163_row1_col0 {
#   background-color: #e0422f;
#   color: #f1f1f1;
# }
# #T_a3163_row2_col0 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_a3163_row3_col0 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_a3163_row4_col0 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_a3163_row5_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a3163">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3163_level0_col0" class="col_heading level0 col0" >ltv_30</th>
#       <th id="T_a3163_level0_col1" class="col_heading level0 col1" >n_users</th>
#       <th id="T_a3163_level0_col2" class="col_heading level0 col2" >%_users</th>
#       <th id="T_a3163_level0_col3" class="col_heading level0 col3" >%_rev</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >battles_won_d0_q</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3163_level0_row0" class="row_heading level0 row0" >0.000</th>
#       <td id="T_a3163_row0_col0" class="data row0 col0" >65.66</td>
#       <td id="T_a3163_row0_col1" class="data row0 col1" >2 787</td>
#       <td id="T_a3163_row0_col2" class="data row0 col2" >57.3%</td>
#       <td id="T_a3163_row0_col3" class="data row0 col3" >25.9%</td>
#     </tr>
#     <tr>
#       <th id="T_a3163_level0_row1" class="row_heading level0 row1" >0.999</th>
#       <td id="T_a3163_row1_col0" class="data row1 col0" >130.27</td>
#       <td id="T_a3163_row1_col1" class="data row1 col1" >667</td>
#       <td id="T_a3163_row1_col2" class="data row1 col2" >13.7%</td>
#       <td id="T_a3163_row1_col3" class="data row1 col3" >12.3%</td>
#     </tr>
#     <tr>
#       <th id="T_a3163_level0_row2" class="row_heading level0 row2" >2.000</th>
#       <td id="T_a3163_row2_col0" class="data row2 col0" >119.79</td>
#       <td id="T_a3163_row2_col1" class="data row2 col1" >228</td>
#       <td id="T_a3163_row2_col2" class="data row2 col2" >4.7%</td>
#       <td id="T_a3163_row2_col3" class="data row2 col3" >3.9%</td>
#     </tr>
#     <tr>
#       <th id="T_a3163_level0_row3" class="row_heading level0 row3" >4.000</th>
#       <td id="T_a3163_row3_col0" class="data row3 col0" >217.29</td>
#       <td id="T_a3163_row3_col1" class="data row3 col1" >364</td>
#       <td id="T_a3163_row3_col2" class="data row3 col2" >7.5%</td>
#       <td id="T_a3163_row3_col3" class="data row3 col3" >11.2%</td>
#     </tr>
#     <tr>
#       <th id="T_a3163_level0_row4" class="row_heading level0 row4" >12.000</th>
#       <td id="T_a3163_row4_col0" class="data row4 col0" >247.84</td>
#       <td id="T_a3163_row4_col1" class="data row4 col1" >406</td>
#       <td id="T_a3163_row4_col2" class="data row4 col2" >8.4%</td>
#       <td id="T_a3163_row4_col3" class="data row4 col3" >14.2%</td>
#     </tr>
#     <tr>
#       <th id="T_a3163_level0_row5" class="row_heading level0 row5" >30.000</th>
#       <td id="T_a3163_row5_col0" class="data row5 col0" >559.05</td>
#       <td id="T_a3163_row5_col1" class="data row5 col1" >410</td>
#       <td id="T_a3163_row5_col2" class="data row5 col2" >8.4%</td>
#       <td id="T_a3163_row5_col3" class="data row5 col3" >32.5%</td>
#     </tr>
#   </tbody>
# </table>

# %%
get_target_pivot(df, col='battles_won_d7_q', target_col=TARGET)
# Out:
# <style type="text/css">
# #T_da80a_row0_col0, #T_da80a_row1_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_da80a_row2_col0 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_da80a_row3_col0 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_da80a_row4_col0 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_da80a_row5_col0 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_da80a_row6_col0 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_da80a_row7_col0 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_da80a_row8_col0 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_da80a_row9_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_da80a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da80a_level0_col0" class="col_heading level0 col0" >ltv_30</th>
#       <th id="T_da80a_level0_col1" class="col_heading level0 col1" >n_users</th>
#       <th id="T_da80a_level0_col2" class="col_heading level0 col2" >%_users</th>
#       <th id="T_da80a_level0_col3" class="col_heading level0 col3" >%_rev</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >battles_won_d7_q</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da80a_level0_row0" class="row_heading level0 row0" >0.000</th>
#       <td id="T_da80a_row0_col0" class="data row0 col0" >1.79</td>
#       <td id="T_da80a_row0_col1" class="data row0 col1" >2 186</td>
#       <td id="T_da80a_row0_col2" class="data row0 col2" >45.0%</td>
#       <td id="T_da80a_row0_col3" class="data row0 col3" >0.6%</td>
#     </tr>
#     <tr>
#       <th id="T_da80a_level0_row1" class="row_heading level0 row1" >0.999</th>
#       <td id="T_da80a_row1_col0" class="data row1 col0" >3.33</td>
#       <td id="T_da80a_row1_col1" class="data row1 col1" >298</td>
#       <td id="T_da80a_row1_col2" class="data row1 col2" >6.1%</td>
#       <td id="T_da80a_row1_col3" class="data row1 col3" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_da80a_level0_row2" class="row_heading level0 row2" >1.222</th>
#       <td id="T_da80a_row2_col0" class="data row2 col0" >13.99</td>
#       <td id="T_da80a_row2_col1" class="data row2 col1" >329</td>
#       <td id="T_da80a_row2_col2" class="data row2 col2" >6.8%</td>
#       <td id="T_da80a_row2_col3" class="data row2 col3" >0.7%</td>
#     </tr>
#     <tr>
#       <th id="T_da80a_level0_row3" class="row_heading level0 row3" >4.000</th>
#       <td id="T_da80a_row3_col0" class="data row3 col0" >45.51</td>
#       <td id="T_da80a_row3_col1" class="data row3 col1" >284</td>
#       <td id="T_da80a_row3_col2" class="data row3 col2" >5.8%</td>
#       <td id="T_da80a_row3_col3" class="data row3 col3" >1.8%</td>
#     </tr>
#     <tr>
#       <th id="T_da80a_level0_row4" class="row_heading level0 row4" >12.000</th>
#       <td id="T_da80a_row4_col0" class="data row4 col0" >90.42</td>
#       <td id="T_da80a_row4_col1" class="data row4 col1" >293</td>
#       <td id="T_da80a_row4_col2" class="data row4 col2" >6.0%</td>
#       <td id="T_da80a_row4_col3" class="data row4 col3" >3.8%</td>
#     </tr>
#     <tr>
#       <th id="T_da80a_level0_row5" class="row_heading level0 row5" >22.000</th>
#       <td id="T_da80a_row5_col0" class="data row5 col0" >175.23</td>
#       <td id="T_da80a_row5_col1" class="data row5 col1" >294</td>
#       <td id="T_da80a_row5_col2" class="data row5 col2" >6.0%</td>
#       <td id="T_da80a_row5_col3" class="data row5 col3" >7.3%</td>
#     </tr>
#     <tr>
#       <th id="T_da80a_level0_row6" class="row_heading level0 row6" >35.000</th>
#       <td id="T_da80a_row6_col0" class="data row6 col0" >207.82</td>
#       <td id="T_da80a_row6_col1" class="data row6 col1" >288</td>
#       <td id="T_da80a_row6_col2" class="data row6 col2" >5.9%</td>
#       <td id="T_da80a_row6_col3" class="data row6 col3" >8.5%</td>
#     </tr>
#     <tr>
#       <th id="T_da80a_level0_row7" class="row_heading level0 row7" >55.000</th>
#       <td id="T_da80a_row7_col0" class="data row7 col0" >288.74</td>
#       <td id="T_da80a_row7_col1" class="data row7 col1" >302</td>
#       <td id="T_da80a_row7_col2" class="data row7 col2" >6.2%</td>
#       <td id="T_da80a_row7_col3" class="data row7 col3" >12.3%</td>
#     </tr>
#     <tr>
#       <th id="T_da80a_level0_row8" class="row_heading level0 row8" >79.000</th>
#       <td id="T_da80a_row8_col0" class="data row8 col0" >395.66</td>
#       <td id="T_da80a_row8_col1" class="data row8 col1" >292</td>
#       <td id="T_da80a_row8_col2" class="data row8 col2" >6.0%</td>
#       <td id="T_da80a_row8_col3" class="data row8 col3" >16.4%</td>
#     </tr>
#     <tr>
#       <th id="T_da80a_level0_row9" class="row_heading level0 row9" >132.000</th>
#       <td id="T_da80a_row9_col0" class="data row9 col0" >1159.15</td>
#       <td id="T_da80a_row9_col1" class="data row9 col1" >296</td>
#       <td id="T_da80a_row9_col2" class="data row9 col2" >6.1%</td>
#       <td id="T_da80a_row9_col3" class="data row9 col3" >48.6%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3.2. `login`

# %%
df['session_time_d7_q'] = enumerate_float(df['session_time_d7'], q=10, process_zeros=True)

# %%
get_target_pivot(df, col='session_time_d7_q', target_col=TARGET)
# Out:
# <style type="text/css">
# #T_05e6f_row0_col0, #T_05e6f_row1_col0, #T_05e6f_row2_col0, #T_05e6f_row3_col0, #T_05e6f_row4_col0, #T_05e6f_row5_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_05e6f_row6_col0 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_05e6f_row7_col0 {
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_05e6f_row8_col0 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_05e6f_row9_col0 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_05e6f_row10_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_05e6f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05e6f_level0_col0" class="col_heading level0 col0" >ltv_30</th>
#       <th id="T_05e6f_level0_col1" class="col_heading level0 col1" >n_users</th>
#       <th id="T_05e6f_level0_col2" class="col_heading level0 col2" >%_users</th>
#       <th id="T_05e6f_level0_col3" class="col_heading level0 col3" >%_rev</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >session_time_d7_q</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05e6f_level0_row0" class="row_heading level0 row0" >0.000</th>
#       <td id="T_05e6f_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_05e6f_row0_col1" class="data row0 col1" >231</td>
#       <td id="T_05e6f_row0_col2" class="data row0 col2" >4.8%</td>
#       <td id="T_05e6f_row0_col3" class="data row0 col3" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_05e6f_level0_row1" class="row_heading level0 row1" >0.999</th>
#       <td id="T_05e6f_row1_col0" class="data row1 col0" >0.49</td>
#       <td id="T_05e6f_row1_col1" class="data row1 col1" >495</td>
#       <td id="T_05e6f_row1_col2" class="data row1 col2" >10.2%</td>
#       <td id="T_05e6f_row1_col3" class="data row1 col3" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_05e6f_level0_row2" class="row_heading level0 row2" >6.000</th>
#       <td id="T_05e6f_row2_col0" class="data row2 col0" >0.13</td>
#       <td id="T_05e6f_row2_col1" class="data row2 col1" >442</td>
#       <td id="T_05e6f_row2_col2" class="data row2 col2" >9.1%</td>
#       <td id="T_05e6f_row2_col3" class="data row2 col3" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_05e6f_level0_row3" class="row_heading level0 row3" >14.000</th>
#       <td id="T_05e6f_row3_col0" class="data row3 col0" >0.53</td>
#       <td id="T_05e6f_row3_col1" class="data row3 col1" >493</td>
#       <td id="T_05e6f_row3_col2" class="data row3 col2" >10.1%</td>
#       <td id="T_05e6f_row3_col3" class="data row3 col3" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_05e6f_level0_row4" class="row_heading level0 row4" >24.000</th>
#       <td id="T_05e6f_row4_col0" class="data row4 col0" >2.91</td>
#       <td id="T_05e6f_row4_col1" class="data row4 col1" >443</td>
#       <td id="T_05e6f_row4_col2" class="data row4 col2" >9.1%</td>
#       <td id="T_05e6f_row4_col3" class="data row4 col3" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_05e6f_level0_row5" class="row_heading level0 row5" >38.000</th>
#       <td id="T_05e6f_row5_col0" class="data row5 col0" >3.19</td>
#       <td id="T_05e6f_row5_col1" class="data row5 col1" >449</td>
#       <td id="T_05e6f_row5_col2" class="data row5 col2" >9.2%</td>
#       <td id="T_05e6f_row5_col3" class="data row5 col3" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_05e6f_level0_row6" class="row_heading level0 row6" >76.000</th>
#       <td id="T_05e6f_row6_col0" class="data row6 col0" >17.28</td>
#       <td id="T_05e6f_row6_col1" class="data row6 col1" >457</td>
#       <td id="T_05e6f_row6_col2" class="data row6 col2" >9.4%</td>
#       <td id="T_05e6f_row6_col3" class="data row6 col3" >1.1%</td>
#     </tr>
#     <tr>
#       <th id="T_05e6f_level0_row7" class="row_heading level0 row7" >167.000</th>
#       <td id="T_05e6f_row7_col0" class="data row7 col0" >45.46</td>
#       <td id="T_05e6f_row7_col1" class="data row7 col1" >466</td>
#       <td id="T_05e6f_row7_col2" class="data row7 col2" >9.6%</td>
#       <td id="T_05e6f_row7_col3" class="data row7 col3" >3.0%</td>
#     </tr>
#     <tr>
#       <th id="T_05e6f_level0_row8" class="row_heading level0 row8" >310.000</th>
#       <td id="T_05e6f_row8_col0" class="data row8 col0" >128.03</td>
#       <td id="T_05e6f_row8_col1" class="data row8 col1" >460</td>
#       <td id="T_05e6f_row8_col2" class="data row8 col2" >9.5%</td>
#       <td id="T_05e6f_row8_col3" class="data row8 col3" >8.3%</td>
#     </tr>
#     <tr>
#       <th id="T_05e6f_level0_row9" class="row_heading level0 row9" >509.000</th>
#       <td id="T_05e6f_row9_col0" class="data row9 col0" >196.57</td>
#       <td id="T_05e6f_row9_col1" class="data row9 col1" >463</td>
#       <td id="T_05e6f_row9_col2" class="data row9 col2" >9.5%</td>
#       <td id="T_05e6f_row9_col3" class="data row9 col3" >12.9%</td>
#     </tr>
#     <tr>
#       <th id="T_05e6f_level0_row10" class="row_heading level0 row10" >953.000</th>
#       <td id="T_05e6f_row10_col0" class="data row10 col0" >1131.45</td>
#       <td id="T_05e6f_row10_col1" class="data row10 col1" >463</td>
#       <td id="T_05e6f_row10_col2" class="data row10 col2" >9.5%</td>
#       <td id="T_05e6f_row10_col3" class="data row10 col3" >74.2%</td>
#     </tr>
#   </tbody>
# </table>

# %%
get_target_pivot(df, col='inactive_d1', target_col=TARGET)
# Out:
# <style type="text/css">
# #T_b057f_row0_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_b057f_row1_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b057f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b057f_level0_col0" class="col_heading level0 col0" >ltv_30</th>
#       <th id="T_b057f_level0_col1" class="col_heading level0 col1" >n_users</th>
#       <th id="T_b057f_level0_col2" class="col_heading level0 col2" >%_users</th>
#       <th id="T_b057f_level0_col3" class="col_heading level0 col3" >%_rev</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >inactive_d1</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b057f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b057f_row0_col0" class="data row0 col0" >268.98</td>
#       <td id="T_b057f_row0_col1" class="data row0 col1" >2 408</td>
#       <td id="T_b057f_row0_col2" class="data row0 col2" >49.5%</td>
#       <td id="T_b057f_row0_col3" class="data row0 col3" >91.7%</td>
#     </tr>
#     <tr>
#       <th id="T_b057f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b057f_row1_col0" class="data row1 col0" >23.81</td>
#       <td id="T_b057f_row1_col1" class="data row1 col1" >2 454</td>
#       <td id="T_b057f_row1_col2" class="data row1 col2" >50.5%</td>
#       <td id="T_b057f_row1_col3" class="data row1 col3" >8.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
get_target_pivot(df, col='n_active_days', target_col=TARGET)
# Out:
# <style type="text/css">
# #T_4560b_row0_col0, #T_4560b_row1_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_4560b_row2_col0 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_4560b_row3_col0 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_4560b_row4_col0 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_4560b_row5_col0 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_4560b_row6_col0 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_4560b_row7_col0 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_4560b_row8_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4560b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4560b_level0_col0" class="col_heading level0 col0" >ltv_30</th>
#       <th id="T_4560b_level0_col1" class="col_heading level0 col1" >n_users</th>
#       <th id="T_4560b_level0_col2" class="col_heading level0 col2" >%_users</th>
#       <th id="T_4560b_level0_col3" class="col_heading level0 col3" >%_rev</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >n_active_days</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4560b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4560b_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_4560b_row0_col1" class="data row0 col1" >39</td>
#       <td id="T_4560b_row0_col2" class="data row0 col2" >0.8%</td>
#       <td id="T_4560b_row0_col3" class="data row0 col3" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_4560b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4560b_row1_col0" class="data row1 col0" >1.89</td>
#       <td id="T_4560b_row1_col1" class="data row1 col1" >1 842</td>
#       <td id="T_4560b_row1_col2" class="data row1 col2" >37.9%</td>
#       <td id="T_4560b_row1_col3" class="data row1 col3" >0.5%</td>
#     </tr>
#     <tr>
#       <th id="T_4560b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4560b_row2_col0" class="data row2 col0" >11.35</td>
#       <td id="T_4560b_row2_col1" class="data row2 col1" >773</td>
#       <td id="T_4560b_row2_col2" class="data row2 col2" >15.9%</td>
#       <td id="T_4560b_row2_col3" class="data row2 col3" >1.2%</td>
#     </tr>
#     <tr>
#       <th id="T_4560b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4560b_row3_col0" class="data row3 col0" >21.78</td>
#       <td id="T_4560b_row3_col1" class="data row3 col1" >488</td>
#       <td id="T_4560b_row3_col2" class="data row3 col2" >10.0%</td>
#       <td id="T_4560b_row3_col3" class="data row3 col3" >1.5%</td>
#     </tr>
#     <tr>
#       <th id="T_4560b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4560b_row4_col0" class="data row4 col0" >49.79</td>
#       <td id="T_4560b_row4_col1" class="data row4 col1" >314</td>
#       <td id="T_4560b_row4_col2" class="data row4 col2" >6.5%</td>
#       <td id="T_4560b_row4_col3" class="data row4 col3" >2.2%</td>
#     </tr>
#     <tr>
#       <th id="T_4560b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4560b_row5_col0" class="data row5 col0" >77.10</td>
#       <td id="T_4560b_row5_col1" class="data row5 col1" >238</td>
#       <td id="T_4560b_row5_col2" class="data row5 col2" >4.9%</td>
#       <td id="T_4560b_row5_col3" class="data row5 col3" >2.6%</td>
#     </tr>
#     <tr>
#       <th id="T_4560b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4560b_row6_col0" class="data row6 col0" >261.08</td>
#       <td id="T_4560b_row6_col1" class="data row6 col1" >209</td>
#       <td id="T_4560b_row6_col2" class="data row6 col2" >4.3%</td>
#       <td id="T_4560b_row6_col3" class="data row6 col3" >7.7%</td>
#     </tr>
#     <tr>
#       <th id="T_4560b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4560b_row7_col0" class="data row7 col0" >354.15</td>
#       <td id="T_4560b_row7_col1" class="data row7 col1" >312</td>
#       <td id="T_4560b_row7_col2" class="data row7 col2" >6.4%</td>
#       <td id="T_4560b_row7_col3" class="data row7 col3" >15.6%</td>
#     </tr>
#     <tr>
#       <th id="T_4560b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4560b_row8_col0" class="data row8 col0" >748.40</td>
#       <td id="T_4560b_row8_col1" class="data row8 col1" >647</td>
#       <td id="T_4560b_row8_col2" class="data row8 col2" >13.3%</td>
#       <td id="T_4560b_row8_col3" class="data row8 col3" >68.6%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3.3. `wealth_on_login`

# %%
# get_target_pivot(df, col='wealth_on_login_max_d0', target_col=TARGET)

# %%
# get_target_pivot(df, col='wealth_on_login_max_d7', target_col=TARGET)

# %%
get_target_pivot(df, col='wealth_on_login_max_d0=802', target_col=TARGET)
# Out:
# <style type="text/css">
# #T_e2c91_row0_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_e2c91_row1_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e2c91">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2c91_level0_col0" class="col_heading level0 col0" >ltv_30</th>
#       <th id="T_e2c91_level0_col1" class="col_heading level0 col1" >n_users</th>
#       <th id="T_e2c91_level0_col2" class="col_heading level0 col2" >%_users</th>
#       <th id="T_e2c91_level0_col3" class="col_heading level0 col3" >%_rev</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >wealth_on_login_max_d0=802</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2c91_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e2c91_row0_col0" class="data row0 col0" >235.18</td>
#       <td id="T_e2c91_row0_col1" class="data row0 col1" >2 350</td>
#       <td id="T_e2c91_row0_col2" class="data row0 col2" >48.3%</td>
#       <td id="T_e2c91_row0_col3" class="data row0 col3" >78.3%</td>
#     </tr>
#     <tr>
#       <th id="T_e2c91_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e2c91_row1_col0" class="data row1 col0" >61.10</td>
#       <td id="T_e2c91_row1_col1" class="data row1 col1" >2 512</td>
#       <td id="T_e2c91_row1_col2" class="data row1 col2" >51.7%</td>
#       <td id="T_e2c91_row1_col3" class="data row1 col3" >21.7%</td>
#     </tr>
#   </tbody>
# </table>

# %%
get_target_pivot(df, col='wealth_on_login_max_d7=802', target_col=TARGET)
# Out:
# <style type="text/css">
# #T_32f49_row0_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_32f49_row1_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_32f49">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32f49_level0_col0" class="col_heading level0 col0" >ltv_30</th>
#       <th id="T_32f49_level0_col1" class="col_heading level0 col1" >n_users</th>
#       <th id="T_32f49_level0_col2" class="col_heading level0 col2" >%_users</th>
#       <th id="T_32f49_level0_col3" class="col_heading level0 col3" >%_rev</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >wealth_on_login_max_d7=802</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_32f49_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_32f49_row0_col0" class="data row0 col0" >217.13</td>
#       <td id="T_32f49_row0_col1" class="data row0 col1" >3 248</td>
#       <td id="T_32f49_row0_col2" class="data row0 col2" >66.8%</td>
#       <td id="T_32f49_row0_col3" class="data row0 col3" >99.9%</td>
#     </tr>
#     <tr>
#       <th id="T_32f49_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_32f49_row1_col0" class="data row1 col0" >0.56</td>
#       <td id="T_32f49_row1_col1" class="data row1 col1" >1 614</td>
#       <td id="T_32f49_row1_col2" class="data row1 col2" >33.2%</td>
#       <td id="T_32f49_row1_col3" class="data row1 col3" >0.1%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3.4. `finish_quest`

# %%
df['finish_quest_sum_d7_q'] = enumerate_float(df['finish_quest_sum_d7'], q=10, process_zeros=True)

# %%
get_target_pivot(df, col='finish_quest_sum_d7_q', target_col=TARGET)
# Out:
# <style type="text/css">
# #T_917e6_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_917e6_row1_col0 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_917e6_row2_col0, #T_917e6_row3_col0 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_917e6_row4_col0 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_917e6_row5_col0 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_917e6_row6_col0 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_917e6_row7_col0 {
#   background-color: #d22b27;
#   color: #f1f1f1;
# }
# #T_917e6_row8_col0 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_917e6_row9_col0 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_917e6_row10_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_917e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_917e6_level0_col0" class="col_heading level0 col0" >ltv_30</th>
#       <th id="T_917e6_level0_col1" class="col_heading level0 col1" >n_users</th>
#       <th id="T_917e6_level0_col2" class="col_heading level0 col2" >%_users</th>
#       <th id="T_917e6_level0_col3" class="col_heading level0 col3" >%_rev</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >finish_quest_sum_d7_q</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_917e6_level0_row0" class="row_heading level0 row0" >0.000</th>
#       <td id="T_917e6_row0_col0" class="data row0 col0" >4.32</td>
#       <td id="T_917e6_row0_col1" class="data row0 col1" >2 723</td>
#       <td id="T_917e6_row0_col2" class="data row0 col2" >56.0%</td>
#       <td id="T_917e6_row0_col3" class="data row0 col3" >1.7%</td>
#     </tr>
#     <tr>
#       <th id="T_917e6_level0_row1" class="row_heading level0 row1" >9.999</th>
#       <td id="T_917e6_row1_col0" class="data row1 col0" >58.90</td>
#       <td id="T_917e6_row1_col1" class="data row1 col1" >274</td>
#       <td id="T_917e6_row1_col2" class="data row1 col2" >5.6%</td>
#       <td id="T_917e6_row1_col3" class="data row1 col3" >2.3%</td>
#     </tr>
#     <tr>
#       <th id="T_917e6_level0_row2" class="row_heading level0 row2" >30.000</th>
#       <td id="T_917e6_row2_col0" class="data row2 col0" >51.59</td>
#       <td id="T_917e6_row2_col1" class="data row2 col1" >186</td>
#       <td id="T_917e6_row2_col2" class="data row2 col2" >3.8%</td>
#       <td id="T_917e6_row2_col3" class="data row2 col3" >1.4%</td>
#     </tr>
#     <tr>
#       <th id="T_917e6_level0_row3" class="row_heading level0 row3" >70.000</th>
#       <td id="T_917e6_row3_col0" class="data row3 col0" >49.93</td>
#       <td id="T_917e6_row3_col1" class="data row3 col1" >194</td>
#       <td id="T_917e6_row3_col2" class="data row3 col2" >4.0%</td>
#       <td id="T_917e6_row3_col3" class="data row3 col3" >1.4%</td>
#     </tr>
#     <tr>
#       <th id="T_917e6_level0_row4" class="row_heading level0 row4" >120.000</th>
#       <td id="T_917e6_row4_col0" class="data row4 col0" >122.65</td>
#       <td id="T_917e6_row4_col1" class="data row4 col1" >218</td>
#       <td id="T_917e6_row4_col2" class="data row4 col2" >4.5%</td>
#       <td id="T_917e6_row4_col3" class="data row4 col3" >3.8%</td>
#     </tr>
#     <tr>
#       <th id="T_917e6_level0_row5" class="row_heading level0 row5" >180.000</th>
#       <td id="T_917e6_row5_col0" class="data row5 col0" >142.37</td>
#       <td id="T_917e6_row5_col1" class="data row5 col1" >208</td>
#       <td id="T_917e6_row5_col2" class="data row5 col2" >4.3%</td>
#       <td id="T_917e6_row5_col3" class="data row5 col3" >4.2%</td>
#     </tr>
#     <tr>
#       <th id="T_917e6_level0_row6" class="row_heading level0 row6" >260.000</th>
#       <td id="T_917e6_row6_col0" class="data row6 col0" >165.53</td>
#       <td id="T_917e6_row6_col1" class="data row6 col1" >203</td>
#       <td id="T_917e6_row6_col2" class="data row6 col2" >4.2%</td>
#       <td id="T_917e6_row6_col3" class="data row6 col3" >4.8%</td>
#     </tr>
#     <tr>
#       <th id="T_917e6_level0_row7" class="row_heading level0 row7" >378.000</th>
#       <td id="T_917e6_row7_col0" class="data row7 col0" >154.48</td>
#       <td id="T_917e6_row7_col1" class="data row7 col1" >215</td>
#       <td id="T_917e6_row7_col2" class="data row7 col2" >4.4%</td>
#       <td id="T_917e6_row7_col3" class="data row7 col3" >4.7%</td>
#     </tr>
#     <tr>
#       <th id="T_917e6_level0_row8" class="row_heading level0 row8" >570.000</th>
#       <td id="T_917e6_row8_col0" class="data row8 col0" >271.86</td>
#       <td id="T_917e6_row8_col1" class="data row8 col1" >216</td>
#       <td id="T_917e6_row8_col2" class="data row8 col2" >4.4%</td>
#       <td id="T_917e6_row8_col3" class="data row8 col3" >8.3%</td>
#     </tr>
#     <tr>
#       <th id="T_917e6_level0_row9" class="row_heading level0 row9" >910.000</th>
#       <td id="T_917e6_row9_col0" class="data row9 col0" >638.25</td>
#       <td id="T_917e6_row9_col1" class="data row9 col1" >213</td>
#       <td id="T_917e6_row9_col2" class="data row9 col2" >4.4%</td>
#       <td id="T_917e6_row9_col3" class="data row9 col3" >19.3%</td>
#     </tr>
#     <tr>
#       <th id="T_917e6_level0_row10" class="row_heading level0 row10" >1380.000</th>
#       <td id="T_917e6_row10_col0" class="data row10 col0" >1609.11</td>
#       <td id="T_917e6_row10_col1" class="data row10 col1" >212</td>
#       <td id="T_917e6_row10_col2" class="data row10 col2" >4.4%</td>
#       <td id="T_917e6_row10_col3" class="data row10 col3" >48.3%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3.5. `level_up`

# %%
get_target_pivot(df, col='level_up_max_d0', target_col=TARGET)
# Out:
# <style type="text/css">
# #T_6aa89_row0_col0, #T_6aa89_row1_col0, #T_6aa89_row3_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_6aa89_row2_col0 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_6aa89_row4_col0, #T_6aa89_row7_col0 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_6aa89_row5_col0, #T_6aa89_row11_col0 {
#   background-color: #bb1526;
#   color: #f1f1f1;
# }
# #T_6aa89_row6_col0, #T_6aa89_row16_col0 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_6aa89_row8_col0 {
#   background-color: #b10b26;
#   color: #f1f1f1;
# }
# #T_6aa89_row9_col0 {
#   background-color: #bd1726;
#   color: #f1f1f1;
# }
# #T_6aa89_row10_col0 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_6aa89_row12_col0 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_6aa89_row13_col0 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_6aa89_row14_col0, #T_6aa89_row15_col0 {
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_6aa89_row17_col0 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_6aa89_row18_col0 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_6aa89_row19_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_6aa89_row20_col0 {
#   background-color: #f99355;
#   color: #000000;
# }
# </style>
# <table id="T_6aa89">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6aa89_level0_col0" class="col_heading level0 col0" >ltv_30</th>
#       <th id="T_6aa89_level0_col1" class="col_heading level0 col1" >n_users</th>
#       <th id="T_6aa89_level0_col2" class="col_heading level0 col2" >%_users</th>
#       <th id="T_6aa89_level0_col3" class="col_heading level0 col3" >%_rev</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >level_up_max_d0</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6aa89_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6aa89_row0_col0" class="data row0 col0" >65.33</td>
#       <td id="T_6aa89_row0_col1" class="data row0 col1" >2 306</td>
#       <td id="T_6aa89_row0_col2" class="data row0 col2" >47.4%</td>
#       <td id="T_6aa89_row0_col3" class="data row0 col3" >21.3%</td>
#     </tr>
#     <tr>
#       <th id="T_6aa89_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_6aa89_row1_col0" class="data row1 col0" >58.09</td>
#       <td id="T_6aa89_row1_col1" class="data row1 col1" >320</td>
#       <td id="T_6aa89_row1_col2" class="data row1 col2" >6.6%</td>
#       <td id="T_6aa89_row1_col3" class="data row1 col3" >2.6%</td>
#     </tr>
#     <tr>
#       <th id="T_6aa89_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_6aa89_row2_col0" class="data row2 col0" >109.40</td>
#       <td id="T_6aa89_row2_col1" class="data row2 col1" >766</td>
#       <td id="T_6aa89_row2_col2" class="data row2 col2" >15.8%</td>
#       <td id="T_6aa89_row2_col3" class="data row2 col3" >11.9%</td>
#     </tr>
#     <tr>
#       <th id="T_6aa89_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_6aa89_row3_col0" class="data row3 col0" >74.63</td>
#       <td id="T_6aa89_row3_col1" class="data row3 col1" >225</td>
#       <td id="T_6aa89_row3_col2" class="data row3 col2" >4.6%</td>
#       <td id="T_6aa89_row3_col3" class="data row3 col3" >2.4%</td>
#     </tr>
#     <tr>
#       <th id="T_6aa89_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_6aa89_row4_col0" class="data row4 col0" >166.45</td>
#       <td id="T_6aa89_row4_col1" class="data row4 col1" >177</td>
#       <td id="T_6aa89_row4_col2" class="data row4 col2" >3.6%</td>
#       <td id="T_6aa89_row4_col3" class="data row4 col3" >4.2%</td>
#     </tr>
#     <tr>
#       <th id="T_6aa89_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_6aa89_row5_col0" class="data row5 col0" >387.00</td>
#       <td id="T_6aa89_row5_col1" class="data row5 col1" >49</td>
#       <td id="T_6aa89_row5_col2" class="data row5 col2" >1.0%</td>
#       <td id="T_6aa89_row5_col3" class="data row5 col3" >2.7%</td>
#     </tr>
#     <tr>
#       <th id="T_6aa89_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_6aa89_row6_col0" class="data row6 col0" >207.96</td>
#       <td id="T_6aa89_row6_col1" class="data row6 col1" >91</td>
#       <td id="T_6aa89_row6_col2" class="data row6 col2" >1.9%</td>
#       <td id="T_6aa89_row6_col3" class="data row6 col3" >2.7%</td>
#     </tr>
#     <tr>
#       <th id="T_6aa89_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_6aa89_row7_col0" class="data row7 col0" >169.25</td>
#       <td id="T_6aa89_row7_col1" class="data row7 col1" >139</td>
#       <td id="T_6aa89_row7_col2" class="data row7 col2" >2.9%</td>
#       <td id="T_6aa89_row7_col3" class="data row7 col3" >3.3%</td>
#     </tr>
#     <tr>
#       <th id="T_6aa89_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_6aa89_row8_col0" class="data row8 col0" >236.80</td>
#       <td id="T_6aa89_row8_col1" class="data row8 col1" >400</td>
#       <td id="T_6aa89_row8_col2" class="data row8 col2" >8.2%</td>
#       <td id="T_6aa89_row8_col3" class="data row8 col3" >13.4%</td>
#     </tr>
#     <tr>
#       <th id="T_6aa89_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_6aa89_row9_col0" class="data row9 col0" >424.60</td>
#       <td id="T_6aa89_row9_col1" class="data row9 col1" >158</td>
#       <td id="T_6aa89_row9_col2" class="data row9 col2" >3.2%</td>
#       <td id="T_6aa89_row9_col3" class="data row9 col3" >9.5%</td>
#     </tr>
#     <tr>
#       <th id="T_6aa89_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_6aa89_row10_col0" class="data row10 col0" >182.93</td>
#       <td id="T_6aa89_row10_col1" class="data row10 col1" >67</td>
#       <td id="T_6aa89_row10_col2" class="data row10 col2" >1.4%</td>
#       <td id="T_6aa89_row10_col3" class="data row10 col3" >1.7%</td>
#     </tr>
#     <tr>
#       <th id="T_6aa89_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_6aa89_row11_col0" class="data row11 col0" >379.38</td>
#       <td id="T_6aa89_row11_col1" class="data row11 col1" >33</td>
#       <td id="T_6aa89_row11_col2" class="data row11 col2" >0.7%</td>
#       <td id="T_6aa89_row11_col3" class="data row11 col3" >1.8%</td>
#     </tr>
#     <tr>
#       <th id="T_6aa89_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_6aa89_row12_col0" class="data row12 col0" >1168.70</td>
#       <td id="T_6aa89_row12_col1" class="data row12 col1" >30</td>
#       <td id="T_6aa89_row12_col2" class="data row12 col2" >0.6%</td>
#       <td id="T_6aa89_row12_col3" class="data row12 col3" >5.0%</td>
#     </tr>
#     <tr>
#       <th id="T_6aa89_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_6aa89_row13_col0" class="data row13 col0" >688.92</td>
#       <td id="T_6aa89_row13_col1" class="data row13 col1" >51</td>
#       <td id="T_6aa89_row13_col2" class="data row13 col2" >1.0%</td>
#       <td id="T_6aa89_row13_col3" class="data row13 col3" >5.0%</td>
#     </tr>
#     <tr>
#       <th id="T_6aa89_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_6aa89_row14_col0" class="data row14 col0" >965.53</td>
#       <td id="T_6aa89_row14_col1" class="data row14 col1" >26</td>
#       <td id="T_6aa89_row14_col2" class="data row14 col2" >0.5%</td>
#       <td id="T_6aa89_row14_col3" class="data row14 col3" >3.6%</td>
#     </tr>
#     <tr>
#       <th id="T_6aa89_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_6aa89_row15_col0" class="data row15 col0" >956.44</td>
#       <td id="T_6aa89_row15_col1" class="data row15 col1" >5</td>
#       <td id="T_6aa89_row15_col2" class="data row15 col2" >0.1%</td>
#       <td id="T_6aa89_row15_col3" class="data row15 col3" >0.7%</td>
#     </tr>
#     <tr>
#       <th id="T_6aa89_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_6aa89_row16_col0" class="data row16 col0" >205.18</td>
#       <td id="T_6aa89_row16_col1" class="data row16 col1" >5</td>
#       <td

# %%
get_target_pivot(df, col='level_up_max_d7', target_col=TARGET)
# Out:
# <style type="text/css">
# #T_30190_row0_col0, #T_30190_row1_col0, #T_30190_row2_col0, #T_30190_row3_col0, #T_30190_row4_col0, #T_30190_row5_col0, #T_30190_row6_col0, #T_30190_row7_col0, #T_30190_row8_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_30190_row9_col0 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_30190_row10_col0 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_30190_row11_col0, #T_30190_row12_col0 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_30190_row13_col0 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_30190_row14_col0, #T_30190_row28_col0 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_30190_row15_col0 {
#   background-color: #bd1726;
#   color: #f1f1f1;
# }
# #T_30190_row16_col0 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_30190_row17_col0 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_30190_row18_col0 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_30190_row19_col0 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_30190_row20_col0 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_30190_row21_col0 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_30190_row22_col0 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_30190_row23_col0 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_30190_row24_col0 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_30190_row25_col0 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_30190_row26_col0 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_30190_row27_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_30190">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30190_level0_col0" class="col_heading level0 col0" >ltv_30</th>
#       <th id="T_30190_level0_col1" class="col_heading level0 col1" >n_users</th>
#       <th id="T_30190_level0_col2" class="col_heading level0 col2" >%_users</th>
#       <th id="T_30190_level0_col3" class="col_heading level0 col3" >%_rev</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >level_up_max_d7</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30190_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_30190_row0_col0" class="data row0 col0" >1.08</td>
#       <td id="T_30190_row0_col1" class="data row0 col1" >1 761</td>
#       <td id="T_30190_row0_col2" class="data row0 col2" >36.2%</td>
#       <td id="T_30190_row0_col3" class="data row0 col3" >0.3%</td>
#     </tr>
#     <tr>
#       <th id="T_30190_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_30190_row1_col0" class="data row1 col0" >1.19</td>
#       <td id="T_30190_row1_col1" class="data row1 col1" >280</td>
#       <td id="T_30190_row1_col2" class="data row1 col2" >5.8%</td>
#       <td id="T_30190_row1_col3" class="data row1 col3" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_30190_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_30190_row2_col0" class="data row2 col0" >2.14</td>
#       <td id="T_30190_row2_col1" class="data row2 col1" >543</td>
#       <td id="T_30190_row2_col2" class="data row2 col2" >11.2%</td>
#       <td id="T_30190_row2_col3" class="data row2 col3" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_30190_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_30190_row3_col0" class="data row3 col0" >5.71</td>
#       <td id="T_30190_row3_col1" class="data row3 col1" >171</td>
#       <td id="T_30190_row3_col2" class="data row3 col2" >3.5%</td>
#       <td id="T_30190_row3_col3" class="data row3 col3" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_30190_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_30190_row4_col0" class="data row4 col0" >4.86</td>
#       <td id="T_30190_row4_col1" class="data row4 col1" >89</td>
#       <td id="T_30190_row4_col2" class="data row4 col2" >1.8%</td>
#       <td id="T_30190_row4_col3" class="data row4 col3" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_30190_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_30190_row5_col0" class="data row5 col0" >3.08</td>
#       <td id="T_30190_row5_col1" class="data row5 col1" >28</td>
#       <td id="T_30190_row5_col2" class="data row5 col2" >0.6%</td>
#       <td id="T_30190_row5_col3" class="data row5 col3" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_30190_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_30190_row6_col0" class="data row6 col0" >5.14</td>
#       <td id="T_30190_row6_col1" class="data row6 col1" >62</td>
#       <td id="T_30190_row6_col2" class="data row6 col2" >1.3%</td>
#       <td id="T_30190_row6_col3" class="data row6 col3" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_30190_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_30190_row7_col0" class="data row7 col0" >7.16</td>
#       <td id="T_30190_row7_col1" class="data row7 col1" >84</td>
#       <td id="T_30190_row7_col2" class="data row7 col2" >1.7%</td>
#       <td id="T_30190_row7_col3" class="data row7 col3" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_30190_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_30190_row8_col0" class="data row8 col0" >28.85</td>
#       <td id="T_30190_row8_col1" class="data row8 col1" >297</td>
#       <td id="T_30190_row8_col2" class="data row8 col2" >6.1%</td>
#       <td id="T_30190_row8_col3" class="data row8 col3" >1.2%</td>
#     </tr>
#     <tr>
#       <th id="T_30190_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_30190_row9_col0" class="data row9 col0" >79.47</td>
#       <td id="T_30190_row9_col1" class="data row9 col1" >333</td>
#       <td id="T_30190_row9_col2" class="data row9 col2" >6.8%</td>
#       <td id="T_30190_row9_col3" class="data row9 col3" >3.7%</td>
#     </tr>
#     <tr>
#       <th id="T_30190_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_30190_row10_col0" class="data row10 col0" >205.23</td>
#       <td id="T_30190_row10_col1" class="data row10 col1" >189</td>
#       <td id="T_30190_row10_col2" class="data row10 col2" >3.9%</td>
#       <td id="T_30190_row10_col3" class="data row10 col3" >5.5%</td>
#     </tr>
#     <tr>
#       <th id="T_30190_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_30190_row11_col0" class="data row11 col0" >114.75</td>
#       <td id="T_30190_row11_col1" class="data row11 col1" >137</td>
#       <td id="T_30190_row11_col2" class="data row11 col2" >2.8%</td>
#       <td id="T_30190_row11_col3" class="data row11 col3" >2.2%</td>
#     </tr>
#     <tr>
#       <th id="T_30190_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_30190_row12_col0" class="data row12 col0" >109.71</td>
#       <td id="T_30190_row12_col1" class="data row12 col1" >142</td>
#       <td id="T_30190_row12_col2" class="data row12 col2" >2.9%</td>
#       <td id="T_30190_row12_col3" class="data row12 col3" >2.2%</td>
#     </tr>
#     <tr>
#       <th id="T_30190_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_30190_row13_col0" class="data row13 col0" >248.97</td>
#       <td id="T_30190_row13_col1" class="data row13 col1" >299</td>
#       <td id="T_30190_row13_col2" class="data row13 col2" >6.1%</td>
#       <td id="T_30190_row13_col3" class="data row13 col3" >10.5%</td>
#     </tr>
#     <tr>
#       <th id="T_30190_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_30190_row14_col0" class="data row14 col0" >447.47</td>
#       <td id="T_30190_row14_col1" class="data row14 col1" >148</td>
#       <td id="T_30190_row14_col2" class="data row14 col2" >3.0%</td>
#       <td id="T_30190_row14_col3" class="data row14 col3" >9.4%</td>
#     </tr>
#     <tr>
#       <th id="T_30190_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_30190_row15_col0" class="data row15 col0" >580.64</td>
#       <td id="T_30190_row15_col1" class="data row15 col1" >86</td>
#       <td id="T_30190_row15_

# %% [markdown]
# ### 3.6. `payment`

# %%
df['payment_sum_d0_q'] = enumerate_float(df['payment_sum_d0'], q=10, process_zeros=True)
df['payment_sum_d7_q'] = enumerate_float(df['payment_sum_d7'], q=10, process_zeros=True)

# %%
get_target_pivot(df, col='payment_sum_d0_q', target_col=TARGET)
# Out:
# <style type="text/css">
# #T_0ea03_row0_col0, #T_0ea03_row2_col0 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_0ea03_row1_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_0ea03_row3_col0 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_0ea03_row4_col0, #T_0ea03_row6_col0 {
#   background-color: #be1827;
#   color: #f1f1f1;
# }
# #T_0ea03_row5_col0 {
#   background-color: #d42d27;
#   color: #f1f1f1;
# }
# #T_0ea03_row7_col0 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_0ea03_row8_col0 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_0ea03_row9_col0 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_0ea03_row10_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0ea03">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0ea03_level0_col0" class="col_heading level0 col0" >ltv_30</th>
#       <th id="T_0ea03_level0_col1" class="col_heading level0 col1" >n_users</th>
#       <th id="T_0ea03_level0_col2" class="col_heading level0 col2" >%_users</th>
#       <th id="T_0ea03_level0_col3" class="col_heading level0 col3" >%_rev</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >payment_sum_d0_q</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ea03_level0_row0" class="row_heading level0 row0" >0.000</th>
#       <td id="T_0ea03_row0_col0" class="data row0 col0" >99.56</td>
#       <td id="T_0ea03_row0_col1" class="data row0 col1" >4 306</td>
#       <td id="T_0ea03_row0_col2" class="data row0 col2" >88.6%</td>
#       <td id="T_0ea03_row0_col3" class="data row0 col3" >60.7%</td>
#     </tr>
#     <tr>
#       <th id="T_0ea03_level0_row1" class="row_heading level0 row1" >11.108</th>
#       <td id="T_0ea03_row1_col0" class="data row1 col0" >68.97</td>
#       <td id="T_0ea03_row1_col1" class="data row1 col1" >56</td>
#       <td id="T_0ea03_row1_col2" class="data row1 col2" >1.2%</td>
#       <td id="T_0ea03_row1_col3" class="data row1 col3" >0.5%</td>
#     </tr>
#     <tr>
#       <th id="T_0ea03_level0_row2" class="row_heading level0 row2" >23.771</th>
#       <td id="T_0ea03_row2_col0" class="data row2 col0" >100.08</td>
#       <td id="T_0ea03_row2_col1" class="data row2 col1" >69</td>
#       <td id="T_0ea03_row2_col2" class="data row2 col2" >1.4%</td>
#       <td id="T_0ea03_row2_col3" class="data row2 col3" >1.0%</td>
#     </tr>
#     <tr>
#       <th id="T_0ea03_level0_row3" class="row_heading level0 row3" >24.402</th>
#       <td id="T_0ea03_row3_col0" class="data row3 col0" >287.58</td>
#       <td id="T_0ea03_row3_col1" class="data row3 col1" >54</td>
#       <td id="T_0ea03_row3_col2" class="data row3 col2" >1.1%</td>
#       <td id="T_0ea03_row3_col3" class="data row3 col3" >2.2%</td>
#     </tr>
#     <tr>
#       <th id="T_0ea03_level0_row4" class="row_heading level0 row4" >24.451</th>
#       <td id="T_0ea03_row4_col0" class="data row4 col0" >215.18</td>
#       <td id="T_0ea03_row4_col1" class="data row4 col1" >44</td>
#       <td id="T_0ea03_row4_col2" class="data row4 col2" >0.9%</td>
#       <td id="T_0ea03_row4_col3" class="data row4 col3" >1.3%</td>
#     </tr>
#     <tr>
#       <th id="T_0ea03_level0_row5" class="row_heading level0 row5" >26.921</th>
#       <td id="T_0ea03_row5_col0" class="data row5 col0" >335.46</td>
#       <td id="T_0ea03_row5_col1" class="data row5 col1" >55</td>
#       <td id="T_0ea03_row5_col2" class="data row5 col2" >1.1%</td>
#       <td id="T_0ea03_row5_col3" class="data row5 col3" >2.6%</td>
#     </tr>
#     <tr>
#       <th id="T_0ea03_level0_row6" class="row_heading level0 row6" >27.766</th>
#       <td id="T_0ea03_row6_col0" class="data row6 col0" >212.77</td>
#       <td id="T_0ea03_row6_col1" class="data row6 col1" >56</td>
#       <td id="T_0ea03_row6_col2" class="data row6 col2" >1.2%</td>
#       <td id="T_0ea03_row6_col3" class="data row6 col3" >1.7%</td>
#     </tr>
#     <tr>
#       <th id="T_0ea03_level0_row7" class="row_heading level0 row7" >32.250</th>
#       <td id="T_0ea03_row7_col0" class="data row7 col0" >172.22</td>
#       <td id="T_0ea03_row7_col1" class="data row7 col1" >60</td>
#       <td id="T_0ea03_row7_col2" class="data row7 col2" >1.2%</td>
#       <td id="T_0ea03_row7_col3" class="data row7 col3" >1.5%</td>
#     </tr>
#     <tr>
#       <th id="T_0ea03_level0_row8" class="row_heading level0 row8" >48.804</th>
#       <td id="T_0ea03_row8_col0" class="data row8 col0" >343.64</td>
#       <td id="T_0ea03_row8_col1" class="data row8 col1" >51</td>
#       <td id="T_0ea03_row8_col2" class="data row8 col2" >1.0%</td>
#       <td id="T_0ea03_row8_col3" class="data row8 col3" >2.5%</td>
#     </tr>
#     <tr>
#       <th id="T_0ea03_level0_row9" class="row_heading level0 row9" >62.199</th>
#       <td id="T_0ea03_row9_col0" class="data row9 col0" >458.92</td>
#       <td id="T_0ea03_row9_col1" class="data row9 col1" >56</td>
#       <td id="T_0ea03_row9_col2" class="data row9 col2" >1.2%</td>
#       <td id="T_0ea03_row9_col3" class="data row9 col3" >3.6%</td>
#     </tr>
#     <tr>
#       <th id="T_0ea03_level0_row10" class="row_heading level0 row10" >97.902</th>
#       <td id="T_0ea03_row10_col0" class="data row10 col0" >2867.86</td>
#       <td id="T_0ea03_row10_col1" class="data row10 col1" >55</td>
#       <td id="T_0ea03_row10_col2" class="data row10 col2" >1.1%</td>
#       <td id="T_0ea03_row10_col3" class="data row10 col3" >22.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
get_target_pivot(df, col='payment_sum_d7_q', target_col=TARGET)
# Out:
# <style type="text/css">
# #T_7eabd_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_7eabd_row1_col0, #T_7eabd_row2_col0 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_7eabd_row3_col0 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_7eabd_row4_col0 {
#   background-color: #b10b26;
#   color: #f1f1f1;
# }
# #T_7eabd_row5_col0 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_7eabd_row6_col0 {
#   background-color: #bb1526;
#   color: #f1f1f1;
# }
# #T_7eabd_row7_col0 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_7eabd_row8_col0 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_7eabd_row9_col0 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_7eabd_row10_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7eabd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7eabd_level0_col0" class="col_heading level0 col0" >ltv_30</th>
#       <th id="T_7eabd_level0_col1" class="col_heading level0 col1" >n_users</th>
#       <th id="T_7eabd_level0_col2" class="col_heading level0 col2" >%_users</th>
#       <th id="T_7eabd_level0_col3" class="col_heading level0 col3" >%_rev</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >payment_sum_d7_q</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7eabd_level0_row0" class="row_heading level0 row0" >0.000</th>
#       <td id="T_7eabd_row0_col0" class="data row0 col0" >0.20</td>
#       <td id="T_7eabd_row0_col1" class="data row0 col1" >3 110</td>
#       <td id="T_7eabd_row0_col2" class="data row0 col2" >64.0%</td>
#       <td id="T_7eabd_row0_col3" class="data row0 col3" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_7eabd_level0_row1" class="row_heading level0 row1" >11.072</th>
#       <td id="T_7eabd_row1_col0" class="data row1 col0" >41.31</td>
#       <td id="T_7eabd_row1_col1" class="data row1 col1" >176</td>
#       <td id="T_7eabd_row1_col2" class="data row1 col2" >3.6%</td>
#       <td id="T_7eabd_row1_col3" class="data row1 col3" >1.0%</td>
#     </tr>
#     <tr>
#       <th id="T_7eabd_level0_row2" class="row_heading level0 row2" >23.790</th>
#       <td id="T_7eabd_row2_col0" class="data row2 col0" >46.98</td>
#       <td id="T_7eabd_row2_col1" class="data row2 col1" >254</td>
#       <td id="T_7eabd_row2_col2" class="data row2 col2" >5.2%</td>
#       <td id="T_7eabd_row2_col3" class="data row2 col3" >1.7%</td>
#     </tr>
#     <tr>
#       <th id="T_7eabd_level0_row3" class="row_heading level0 row3" >24.451</th>
#       <td id="T_7eabd_row3_col0" class="data row3 col0" >57.44</td>
#       <td id="T_7eabd_row3_col1" class="data row3 col1" >96</td>
#       <td id="T_7eabd_row3_col2" class="data row3 col2" >2.0%</td>
#       <td id="T_7eabd_row3_col3" class="data row3 col3" >0.8%</td>
#     </tr>
#     <tr>
#       <th id="T_7eabd_level0_row4" class="row_heading level0 row4" >26.903</th>
#       <td id="T_7eabd_row4_col0" class="data row4 col0" >69.55</td>
#       <td id="T_7eabd_row4_col1" class="data row4 col1" >175</td>
#       <td id="T_7eabd_row4_col2" class="data row4 col2" >3.6%</td>
#       <td id="T_7eabd_row4_col3" class="data row4 col3" >1.7%</td>
#     </tr>
#     <tr>
#       <th id="T_7eabd_level0_row5" class="row_heading level0 row5" >29.012</th>
#       <td id="T_7eabd_row5_col0" class="data row5 col0" >77.44</td>
#       <td id="T_7eabd_row5_col1" class="data row5 col1" >175</td>
#       <td id="T_7eabd_row5_col2" class="data row5 col2" >3.6%</td>
#       <td id="T_7eabd_row5_col3" class="data row5 col3" >1.9%</td>
#     </tr>
#     <tr>
#       <th id="T_7eabd_level0_row6" class="row_heading level0 row6" >34.202</th>
#       <td id="T_7eabd_row6_col0" class="data row6 col0" >114.05</td>
#       <td id="T_7eabd_row6_col1" class="data row6 col1" >175</td>
#       <td id="T_7eabd_row6_col2" class="data row6 col2" >3.6%</td>
#       <td id="T_7eabd_row6_col3" class="data row6 col3" >2.8%</td>
#     </tr>
#     <tr>
#       <th id="T_7eabd_level0_row7" class="row_heading level0 row7" >53.579</th>
#       <td id="T_7eabd_row7_col0" class="data row7 col0" >144.03</td>
#       <td id="T_7eabd_row7_col1" class="data row7 col1" >177</td>
#       <td id="T_7eabd_row7_col2" class="data row7 col2" >3.6%</td>
#       <td id="T_7eabd_row7_col3" class="data row7 col3" >3.6%</td>
#     </tr>
#     <tr>
#       <th id="T_7eabd_level0_row8" class="row_heading level0 row8" >73.206</th>
#       <td id="T_7eabd_row8_col0" class="data row8 col0" >261.92</td>
#       <td id="T_7eabd_row8_col1" class="data row8 col1" >173</td>
#       <td id="T_7eabd_row8_col2" class="data row8 col2" >3.6%</td>
#       <td id="T_7eabd_row8_col3" class="data row8 col3" >6.4%</td>
#     </tr>
#     <tr>
#       <th id="T_7eabd_level0_row9" class="row_heading level0 row9" >115.081</th>
#       <td id="T_7eabd_row9_col0" class="data row9 col0" >616.02</td>
#       <td id="T_7eabd_row9_col1" class="data row9 col1" >175</td>
#       <td id="T_7eabd_row9_col2" class="data row9 col2" >3.6%</td>
#       <td id="T_7eabd_row9_col3" class="data row9 col3" >15.3%</td>
#     </tr>
#     <tr>
#       <th id="T_7eabd_level0_row10" class="row_heading level0 row10" >242.689</th>
#       <td id="T_7eabd_row10_col0" class="data row10 col0" >2593.83</td>
#       <td id="T_7eabd_row10_col1" class="data row10 col1" >176</td>
#       <td id="T_7eabd_row10_col2" class="data row10 col2" >3.6%</td>
#       <td id="T_7eabd_row10_col3" class="data row10 col3" >64.6%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 4. Dataset segmentation

# %%
train_df, dev_df = train_test_split(df, test_size=0.2, random_state=0)

# %%
print(train_df.shape)
print(dev_df.shape)
# Out:
# (3889, 44)
# (973, 44)

# %%
df.loc[train_df.index, 'segment'] = 'TRAIN'
df.loc[dev_df.index, 'segment'] = 'DEV'

# %%
df['segment'].value_counts(dropna=False)
# Out:
# segment
# TRAIN    3889
# DEV       973
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Dataset export

# %%
df.columns.tolist()
# Out:
# ['reg_ts',
#  'country',
#  'entry_point',
#  'ltv_30',
#  'entry_point=android',
#  'country_e',
#  'battles_won_d0',
#  'battles_won_d1',
#  'battles_won_d3',
#  'battles_won_d7',
#  'battles_lost_d0',
#  'battles_lost_d1',
#  'battles_lost_d3',
#  'battles_lost_d7',
#  'session_time_d0',
#  'session_time_d1',
#  'session_time_d3',
#  'session_time_d7',
#  'inactive_d1',
#  'n_active_days',
#  'wealth_on_login_max_d0',
#  'wealth_on_login_max_d1',
#  'wealth_on_login_max_d3',
#  'wealth_on_login_max_d7',
#  'wealth_on_login_max_d0=802',
#  'wealth_on_login_max_d7=802',
#  'finish_quest_sum_d0',
#  'finish_quest_sum_d1',
#  'finish_quest_sum_d3',
#  'finish_quest_sum_d7',
#  'level_up_max_d0',
#  'level_up_max_d1',
#  'level_up_max_d3',
#  'level_up_max_d7',
#  'payment_sum_d0',
#  'payment_sum_d1',
#  'payment_sum_d3',
#  'payment_sum_d7',
#  'battles_won_d0_q',
#  'battles_won_d7_q',
#  'session_time_d7_q',
#  'finish_quest_sum_d7_q',
#  'payment_sum_d0_q',
#  'payment_sum_d7_q',
#  'segment']

# %%
FEATURES = [
    'entry_point=android',
    'country_e',
    'battles_won_d0',
    'battles_won_d1',
    'battles_won_d3',
    'battles_won_d7',
    'battles_lost_d0',
    'battles_lost_d1',
    'battles_lost_d3',
    'battles_lost_d7',
    'session_time_d0',
    'session_time_d1',
    'session_time_d3',
    'session_time_d7',
    'inactive_d1',
    'n_active_days',
    'wealth_on_login_max_d0',
    'wealth_on_login_max_d1',
    'wealth_on_login_max_d3',
    'wealth_on_login_max_d7',
    'finish_quest_sum_d0',
    'finish_quest_sum_d1',
    'finish_quest_sum_d3',
    'finish_quest_sum_d7',
    'level_up_max_d0',
    'level_up_max_d1',
    'level_up_max_d3',
    'level_up_max_d7',
    'payment_sum_d0',
    'payment_sum_d1',
    'payment_sum_d3',
    'payment_sum_d7',
    'wealth_on_login_max_d0=802',
    'wealth_on_login_max_d7=802',
]

# %%
EXPORT_COLS = FEATURES + ['segment', TARGET]

# %%
EXPORT_FILE_NAME = 'train_dev.csv'

# %%
export_file_path = os.path.join(DATA_DIR, EXPORT_FILE_NAME)

# %%
df[EXPORT_COLS].to_csv(export_file_path)
